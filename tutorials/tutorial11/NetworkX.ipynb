# %% [markdown]
# `Networkx`
# ====

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import networkx as nx
import codecs
import numpy as np
import operator
import pandas as pd

colors = {"ADJ": "green",
"ADP": "yellow",
"ADV": "grey",
"CONJ": "aqua",
"NOUN": "red",
"PRON": "black",
"VERB": "blue",
"X": "orange",
"ASSOCIATION": "white"
}
POS = map(unicode.strip, codecs.open('UPOS.txt', encoding='utf-8').readlines())
nodes = {}
for line in codecs.open('nodes.txt', encoding='utf-8'):
    line = line.strip()
    node, name = line.split(' ', 1)
    nodes[int(node)] = name

# %% [markdown]
# NetworkX let's us define graphs very easily, and then gives us a lot of different algorithms to analyze it. The steps are simple:
#
# 1. select a graph type: undirected (`Graph`) or directed (`DiGraph`) graph
#
# 2. populate the graph with nodes and/or edges. If we add an edge, the nodes are automatically added
#
#     * we can add individual nodes (`add_node(u)`) or edges (`add_edge(u, v)`), or
#     * add them in batches (`add_nodes_from(x)`, `add_edges_from(x)`)

# %% [markdown]
# Examples
# ---
#
# First, we read in a file that defines the graph. Here, we use the word association data. Each line is one edge between two words. The association strength is the weight of the edge. Since this is a network, and since the association were only elicited one way, we opt for a directed graph here.
#
# We also associate additional information with each node. In this case, the universal POS tag and a color (for plotting).

# %%
G = nx.DiGraph()

LIMIT = 2000

for i, line in enumerate(codecs.open('arcs.txt', encoding='utf-8')):
    line = line.strip()
    start, end, strength = line.split()
    start = int(start)
    end = int(end)
    
    if start < LIMIT and end < LIMIT:
        # add nodes
        G.add_node(nodes[start], POS=POS[start-1], color=colors[POS[start-1]])
        G.add_node(nodes[end], POS=POS[end-1], color=colors[POS[end-1]])

        # add a link
        G.add_edge(nodes[start], nodes[end], weight=float(strength))


G.size()
# Out:
# 554

# %% [markdown]
# Accessing Nodes
# ----
#
# We can look at individual nodes by accessing them like this:
#
# `graph['nodename']`
#
# This gives us a dictionary of the neighboring nodes and the weight of the connections to them.

# %%
G['AMAZE']
# Out:
# {u'AMAZEMENT': {'weight': 0.013},
#  u'ASTONISH': {'weight': 0.059},
#  u'ASTOUND': {'weight': 0.072},
#  u'DAZZLE': {'weight': 0.02},
#  u'ENCHANT': {'weight': 0.013},
#  u'EXCITE': {'weight': 0.065},
#  u'IMPRESSED': {'weight': 0.026},
#  u'STUN': {'weight': 0.039},
#  u'UNBELIEVABLE': {'weight': 0.013},
#  u'WOW': {'weight': 0.059}}

# %% [markdown]
# In order to see the node properties, we have to use a slightly different syntax:
#
# `graph.node['nodename']`

# %%
G.node['AMAZE']
# Out:
# {'POS': u'VERB', 'color': 'blue'}

# %% [markdown]
# Plotting
# ----
#
# `networkx` also gives us the tools to plot our graph. This is where the different node colors come in handy.

# %%
fig, ax = plt.subplots()
fig.set_size_inches(20,20)

nx.draw(G, node_color=[G.node[x]['color'] for x in G.nodes_iter()], ax=ax)
# nx.draw(S, ax=ax)
plt.show()

# %% [markdown]
# Graph Analysis
# ----
#
# We can use some standard measures that assess how important a node is
#
# * degree centrality: this measures to how many other nodes a node $u$ is connected
#
# * betweenness centrality: this measures how often the node is part of a shortest path between other nodes
#
# * Page Rank: this is the algortihm used by Google (and developed by one of its fonders, Larry Page). It takes into account how many nodes link to $u$ and how important those other nodes are.
#
# We compute the values for each node and then enrich our graph by adding the information as another attribute to each node. Luckily, we don't have to do this explicitly for every node, but can do it in batch.

# %%
# compute PageRank
page_rank = nx.pagerank(G)
# set attribute for all nodes
nx.set_node_attributes(G, 'page_rank', page_rank)

# compute degree centrality
degree_centrality = nx.degree_centrality(G)
# set attribute for all nodes
nx.set_node_attributes(G, 'degree_centrality', degree_centrality)

# compute betweenness
betweenness = nx.betweenness_centrality(G)
# set attribute for all nodes
nx.set_node_attributes(G, 'betweenness', betweenness)

# find top ranked nodes
sorted_pr = sorted(page_rank.items(), key=operator.itemgetter(1), reverse=True)
sorted_degree_centrality = sorted(degree_centrality.items(), key=operator.itemgetter(1), reverse=True)

# print the most central nodes
for node_id, degree in sorted_degree_centrality[:5]:
    print node_id, G.node[node_id]
print
for node_id, pr in sorted_pr[:5]:
    print node_id, G.node[node_id]
# Out:
# AMAZE {'color': 'blue', 'betweenness': 0.0, 'degree_centrality': 0.01483679525222552, 'POS': u'VERB', 'page_rank': 0.0010607265961671572}
# TO {'color': 'white', 'betweenness': 0.0, 'degree_centrality': 0.01483679525222552, 'POS': u'ASSOCIATION', 'page_rank': 0.0070333543635960095}
# ACCOMPLISHED {'color': 'blue', 'betweenness': 0.0, 'degree_centrality': 0.013353115727002967, 'POS': u'VERB', 'page_rank': 0.0010607265961671572}
# AGE {'color': 'red', 'betweenness': 0.0, 'degree_centrality': 0.010385756676557865, 'POS': u'NOUN', 'page_rank': 0.0010607265961671572}
# ASSOCIATE {'color': 'blue', 'betweenness': 0.0, 'degree_centrality': 0.010385756676557865, 'POS': u'VERB', 'page_rank': 0.0010607265961671572}
#
# TO {'color': 'white', 'betweenness': 0.0, 'degree_centrality': 0.01483679525222552, 'POS': u'ASSOCIATION', 'page_rank': 0.0070333543635960095}
# ALLY {'color': 'white', 'betweenness': 0.0, 'degree_centrality': 0.005934718100890208, 'POS': u'ASSOCIATION', 'page_rank': 0.004667197041718459}
# SOMEONE {'color': 'white', 'betweenness': 0.0, 'degree_centrality': 0.008902077151335312, 'POS': u'ASSOCIATION', 'page_rank': 0.004528224146931448}
# ARRANGE {'color': 'white', 'betweenness': 0.0, 'degree_centrality': 0.005934718100890208, 'POS': u'ASSOCIATION', 'page_rank': 0.003951206585616363}
# SHIT {'color': 'white', 'betweenness': 0.0, 'degree_centrality': 0.004451038575667656, 'POS': u'ASSOCIATION', 'page_rank': 0.003765579430330634}

# %% [markdown]
# Note that for a directed graph of this sort, betweenness is 0 for all nodes, since there are no path longer than 1.
#
# We can now plot theses measures against each other in order to get a visual of which nodes are more important according to which measures. We label only the top 10.

# %%
pr = [G.node[nid]['page_rank'] for nid in G.nodes_iter()]
dc = [G.node[nid]['degree_centrality'] for nid in G.nodes_iter()]
pos = [G.node[nid]['POS'] for nid in G.nodes_iter()]
color = [G.node[nid]['color'] for nid in G.nodes_iter()]

tp_data = pd.DataFrame({'id':G.nodes(), 'page_rank':pr, 'degree_centrality':dc, 'POS':pos, 'color':color})


def scatter_plot_importance(g, m1, m2, top=10):
    fig, ax = plt.subplots()
    fig.set_size_inches(20,8)

    for pos in set(tp_data.POS.values):
        g[g.POS == pos].plot(x=m1, y=m2, style='o', ax=ax, c=colors[pos] )

    aggregate = zip(g[m1] + g[m2], g['id'], g[m1], g[m2])
    aggregate.sort(reverse=True)
    for _, label, x, y in aggregate[:top]:
        plt.annotate(label,
                        xy = (x, y), xytext = (-20, 20),
                        textcoords = 'offset points', ha = 'right', va = 'bottom',
                        arrowprops = dict(arrowstyle = '->', connectionstyle = 'arc3,rad=0'))


scatter_plot_importance(tp_data, 'page_rank', 'degree_centrality')

# %% [markdown]
# Let's look at the top nodes and their connections.

# %%
# most_central = tp_data[tp_data['POS'] == 'NOUN'].sort('degree_centrality').tail(3).id.tolist()
most_central = tp_data.sort('degree_centrality').tail(10).id.tolist()

# create a subset of nodes by starting from the most central nodes
subset = most_central

# add some neighbors of each node
for x in most_central:
    subset.extend(G[x].keys()[:5])

print subset
# create subgraph
S = nx.subgraph(G, subset)


# plot the sub-graph
fig, ax = plt.subplots()
fig.set_size_inches(20,20)
nx.draw(S, node_color=[S.node[x]['color'] for x in S.nodes_iter()], ax=ax)
plt.show()
print G.node['GRANDFATHER']
# Out:
# [u'APPROVAL', u'SOMEONE', u'AGREEMENT', u'ABLE', u'ANCESTOR', u'AGE', u'ASSOCIATE', u'ACCOMPLISHED', u'TO', u'AMAZE', u'GRATITUDE', u'NOD', u'CONSENT', u'ACCEPTANCE', u'DISAPPROVAL', u'PACT', u'CONSENT', u'WRITTEN', u'COMPROMISE', u'SETTLEMENT', u'HANDICAPPED', u'CAPABLE', u'BODIED', u'DISABLED', u'TO', u'PREDECESSOR', u'APES', u'INDIANS', u'GRANDFATHER', u'GRANDMOTHER', u'SEVENTEEN', u'TWENTY', u'TWENTY ONE', u'MATURITY', u'EIGHTEEN', u'COLLEAGUE', u'COMPARE', u'ACQUAINTANCE', u'MINGLE', u'DISASSOCIATE', u'ESTABLISHED', u'PRODUCTIVE', u'TALENTED', u'SUCCESSFUL', u'COMPLETED', u'IMPRESSED', u'DAZZLE', u'UNBELIEVABLE', u'ENCHANT', u'WOW']
# {'color': 'white', 'betweenness': 0.0, 'degree_centrality': 0.001483679525222552, 'POS': u'ASSOCIATION', 'page_rank': 0.0012870901666858028}

# %% [markdown]
# Reading
# ====
#
# * http://www.slideshare.net/arnicas/a-quick-and-dirty-intro-to-networkx-and-d3
#
# * http://www.faculty.ucr.edu/~hanneman/nettext/
