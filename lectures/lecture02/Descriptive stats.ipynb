# %%
# %matplotlib inline
import pandas as pd

# %% [markdown]
# ## Outline
#
# We have two purposes today. First, we'll show you how easy it is to calculate various statistics for your datasets. With `pandas` you wield a great deal of power to manipulate variables and instances into whatever form and shape you wish.
#
# Then we'll show you how easy it is to mislead with numbers. Not that we suspect you would want to do that on purpose. Unfortunately the easiest person to fool is yourself.
#
# While making technically correct calculations is easier than ever with `pandas`, the hard part is ensuring that the quantities you chose to highlight are actually meaningful and appropriate for the data.
#
# ### Making comparisons
#
# Arguable the aim of modern science is to make comparisons. Scientists are for instance interested in
#
# - which of two competing drugs work better; or
# - whether a drug is more effective than placebo;
# - if a food supplement has any of the claimed health benefits;
# - if their newly developed sentiment analysis algorithm is actually better than a baseline

# %% [markdown]
# ### Grouping

# %% [markdown]
# ### Merging operations

# %%
prize_winners_age = pd.read_csv("nobel_prize_winners_age.csv", sep=";")
prize_winners_age['last_name'] = [name.strip().split(", ")[0] for name in prize_winners_age['name']]
prize_winners_age.head()
# Out:
#                            name      field  year_birth  year_prize  \
# 0  Van'T Hoff, Jacobus Henricus  Chemistry        1852        1901
# 1         Fischer, Hermann Emil  Chemistry        1852        1902
# 2      Arrhenius, Svante August  Chemistry        1859        1903
# 3           Ramsay, Sir William  Chemistry        1852        1904
# 4            Von Baeyer, Johann  Chemistry        1835        1905
#
#    year_research_mid  year_death  TheoryOrTheoryAndEmpirical  age_highdegree  \
# 0               1885        1911                           1              22
# 1               1895        1919                           0              22
# 2               1884        1927                           1              25
# 3               1894        1916                           0              20
# 4               1873        1917                           0              23
#
#     last_name
# 0  Van'T Hoff
# 1     Fischer
# 2   Arrhenius
# 3      Ramsay
# 4  Von Baeyer

# %%
prize_winners_gender = pd.read_csv("nobel_prize_winners.tsv", sep="\t")
prize_winners_gender['last_name'] = [name.strip().split(" ")[-1] for name in prize_winners_gender['Name']]
prize_winners_gender.head()
# Out:
#    Year     Domain                      Name Nationality Gender     last_name
# 0  2009    Physics            Charles K. Kao       China   Male           Kao
# 1  2009    Physics          Willard S. Boyle         USA   Male         Boyle
# 2  2009    Physics           George E. Smith         USA   Male         Smith
# 3  2009  Chemistry  Venkatraman Ramakrishnan          UK   Male  Ramakrishnan
# 4  2009  Chemistry          Thomas A. Steitz         USA   Male        Steitz

# %%
prize_winners = prize_winners_age.merge(right=prize_winners_gender, how='inner',  
                                        left_on=['year_prize', 'field', 'last_name'], 
                                        right_on=['Year', 'Domain', 'last_name'])
prize_winners.head()
# Out:
#                        name      field  year_birth  year_prize  \
# 0     Fischer, Hermann Emil  Chemistry        1852        1902
# 1  Arrhenius, Svante August  Chemistry        1859        1903
# 2       Ramsay, Sir William  Chemistry        1852        1904
# 3            Moissan, Henri  Chemistry        1852        1906
# 4           Buchner, Eduard  Chemistry        1860        1907
#
#    year_research_mid  year_death  TheoryOrTheoryAndEmpirical  age_highdegree  \
# 0               1895        1919                           0              22
# 1               1884        1927                           1              25
# 2               1894        1916                           0              20
# 3               1898        1907                           0              28
# 4               1897        1917                           0              28
#
#    last_name  Year     Domain                  Name Nationality Gender
# 0    Fischer  1902  Chemistry         Emil Fischer      Germany   Male
# 1  Arrhenius  1903  Chemistry     Svante Arrhenius       Sweden   Male
# 2     Ramsay  1904  Chemistry   Sir William Ramsay           UK   Male
# 3    Moissan  1906  Chemistry        Henri Moissan       France   Male
# 4    Buchner  1907  Chemistry       Eduard Buchner      Germany   Male

# %%
prize_winners = prize_winners.drop(['name', 'Domain', 'Year', 'last_name', 'TheoryOrTheoryAndEmpirical'], axis=1)
prize_winners.columns = [name.lower() for name in prize_winners.columns]
prize_winners.head()
# Out:
#        field  year_birth  year_prize  year_research_mid  year_death  \
# 0  Chemistry        1852        1902               1895        1919
# 1  Chemistry        1859        1903               1884        1927
# 2  Chemistry        1852        1904               1894        1916
# 3  Chemistry        1852        1906               1898        1907
# 4  Chemistry        1860        1907               1897        1917
#
#    age_highdegree                  name nationality gender
# 0              22         Emil Fischer      Germany   Male
# 1              25     Svante Arrhenius       Sweden   Male
# 2              20   Sir William Ramsay           UK   Male
# 3              28        Henri Moissan       France   Male
# 4              28       Eduard Buchner      Germany   Male

# %%
prize_winners['age_death'] = prize_winners['year_death'] - prize_winners['year_birth']
prize_winners['age_prize'] = prize_winners['year_prize'] - prize_winners['year_birth']
prize_winners['age_research_mid'] = prize_winners['year_research_mid'] - prize_winners['year_birth']
prize_winners['degree_to_prize'] = prize_winners['age_prize'] - prize_winners['age_highdegree']
prize_winners['research_mid_to_prize'] = prize_winners['age_prize'] - prize_winners['age_research_mid']
prize_winners
# Out:
#          field  year_birth  year_prize  year_research_mid  year_death  \
# 0    Chemistry        1852        1902               1895        1919
# 1    Chemistry        1859        1903               1884        1927
# 2    Chemistry        1852        1904               1894        1916
# 3    Chemistry        1852        1906               1898        1907
# 4    Chemistry        1860        1907               1897        1917
# 5    Chemistry        1871        1908               1902        1937
# 6    Chemistry        1853        1909               1894        1932
# 7    Chemistry        1847        1910               1884        1931
# 8    Chemistry        1867        1911               1910        1934
# 9    Chemistry        1871        1912               1900        1935
# 10   Chemistry        1854        1912               1897        1941
# 11   Chemistry        1866        1913               1892        1919
# 12   Chemistry        1868        1914               1900        1928
# 13   Chemistry        1872        1915               1913        1942
# 14   Chemistry        1868        1918               1905        1934
# 15   Chemistry        1864        1920               1906        1941
# 16   Chemistry        1877        1921               1909        1956
# 17   Chemistry        1877        1922               1919        1945
# 18   Chemistry        1869        1923               1911        1930
# 19   Chemistry        1865        1925               1903        1929
# 20   Chemistry        1884        1926               1913        1971
# 21   Chemistry        1877        1927               1932        1957
# 22   Chemistry        1876        1928               1919        1958
# 23   Chemistry        1865        1929               1911        1940
# 24   Chemistry        1881        1930               1929        1945
# 25   Chemistry        1884        1931               1912        1949
# 26   Chemistry        1874        1931               1910        1940
# 27   Chemistry        1881        1932               1916        1957
# 28   Chemistry        1893        1934               1931        1981
# 29   Chemistry        1900        1935               1934        1958
# ..         ...         ...         ...                ...         ...
# 471    Physics        1948        1997               1988         NaN
# 472    Physics        1950        1998               1983         NaN
# 473    Physics        1949        1998               1982         NaN
# 474    Physics        1939        1998               1982         NaN
# 475    Physics        1946        1999               1970         NaN
# 476    Physics        1931        1999               1970         NaN
# 477    Physics        1930        2000               1966         NaN
# 478    Physics        1923        2000               1958         NaN
# 479    Physics        1928        2000               1960         NaN
# 480    Physics        1961        2001               1995         NaN
# 481    Physics        1957        2001               1995         NaN
# 482    Physics        1951        2001               1995         NaN
# 483    Physics        1931        2002               1969         NaN
# 484    Physics        1926        2002               1987         NaN
# 485    Physics        1928        2003               1957         NaN
# 486    Physics        1916        2003               1950         NaN
# 487    Physics        1938        2003               1972         NaN
# 488    Physics        1941        2004               1973         NaN
# 489    Physics        1949        2004               1973         NaN
# 490    Physics        1951        2004               1973         NaN
# 491    Physics        1925        2005               1963         NaN
# 492    Physics        1934        2005               2000         NaN
# 493    Physics        1941        2005               1999         NaN
# 494    Physics        1946        2006               1990         NaN
# 495    Physics        1945        2006               1992         NaN
# 496    Physics        1938        2007               1988         NaN
# 497    Physics        1939        2007               1988         NaN
# 498    Physics        1944        2008               1972         NaN
# 499    Physics        1940        2008               1972         NaN
# 500    Physics        1921        2008               1960         NaN
#
#      age_highdegree                     name      nationality  gender  \
# 0                22            Emil Fischer           Germany    Male
# 1                25        Svante Arrhenius            Sweden    Male
# 2                20      Sir William Ramsay                UK    Male
# 3                28           Henri Moissan            France    Male
# 4                28          Eduard Buchner           Germany    Male
# 5                23       Ernest Rutherford   UK, New Zealand    Male
# 6                25         Wilhelm Ostwald           Germany    Male
# 7                22            Otto Wallach           Germany    Male
# 8                36             Marie Curie            France  Female
# 9                30         Victor Grignard            France    Male
# 10               26           Paul Sabatier            France    Male
# 11               24           Alfred Werner       Switzerland    Male
# 12               20    Theodore W. Richards               USA    Male
# 13               22     Richard Willstatter           Germany    Male
# 14               28             Fritz Haber           Germany    Male
# 15               23          Walther Nernst           Germany    Male
# 16               21         Frederick Soddy                UK    Male
# 17               19        Francis W. Aston                UK    Male
# 18               25             Fritz Pregl           Austria    Male
# 19               26       Richard Zsigmondy           Germany    Male
# 20               24            The Svedberg            Sweden    Male
# 21               24        Heinrich Wieland           Germany    Male
# 22               24           Adolf Windaus           Germany    Male
# 23               23           Arthur Harden                UK    Male
# 24               27            Hans Fischer           Germany    Male
# 25               23       Friedrich Bergius           Germany    Male
# 26               24              Carl Bosch           Germany    Male
# 27               25         Irving Langmuir               USA    Male
# 28               30          Harold C. Urey               USA    Male
# 29               30         Frederic Joliot            France    Male
# ..              ...                      ...              ...     ...
# 471              28     William D. Phillips               USA    Male
# 472              29      Robert B. Laughlin               USA    Male
# 473              28        Horst L. Stormer           Germany    Male
# 474              28          Daniel C. Tsui               USA    Male
# 475              26       Gerardus 't Hooft       Netherlands    Male
# 476              32   Martinus J.G. Veltman       Netherlands    Male
# 477              22       Zhores I. Alferov            Russia    Male
# 478              35           Jack S. Kilby               USA    Male
# 479              24         Herbert Kroemer           Germany    Male
# 480              29         Eric A. Cornell               USA    Male
# 481              29       Wolfgang Ketterle           Germany    Male
# 482              26          Carl E. Wieman               USA    Male
# 483              23       Riccardo Giacconi               USA    Male
# 484              29       Masatoshi Koshiba             Japan    Male
# 485              23     Alexei A. Abrikosov       USA, Russia    Male
# 486              26      Vitaly L. Ginzburg            Russia    Male
# 487              26      Anthony J. Leggett           UK, USA    Male
# 488              25          David J. Gross               USA    Male
# 489              25       H. David Politzer               USA    Male
# 490              23           Frank Wilczek               USA    Male
# 491              24          Roy J. Glauber               USA    Male
# 492              27            John L. Hall               USA    Male
# 493              28       Theodor W. Hansch           Germany    Male
# 494              28          John C. Mather               USA    Male
# 495              25         George F. Smoot               USA    Male
# 496              32             Albert Fert            France    Male
# 497              30          Peter Grunberg           Germany    Male
# 498              28         Makoto Kobayashi            Japan    Male
# 499              27        Toshihide Maskawa            Japan    Male
# 500              31           Yoichiro Nambu              USA    Male
#
#      age_death  age_prize  age_research_mid  degree_to_prize  \
# 0           67         50                43               28
# 1           68         44                25               19
# 2           64         52                42               32
# 3           55         54                46               26
# 4           57         47                37               19
# 5           66         37                31               14
# 6           79         56                41               31
# 7           84         63                37               41
# 8           67         44                43                8
# 9           64         41                29               11
# 10          87         58                43               32
# 11          53         47                26               23
# 12          60         46                32               26
# 13          70         43                41               21
# 14          66         50                37               22
# 15          77         56                42               33
# 16          79         44                32               23
# 17          68         45                42               26
# 18          61         54                42               29
# 19          64         60                38               34
# 20          87         42                29               18
# 21          80         50                55               26
# 22          82         52                43               28
# 23          75         64                46               41
# 24          64         49                48               22
# 25          65         47                28               24
# 26          66         57                36               33
# 27          76         51                35               26
# 28          88         41                38               11
# 29          58         35                34                5
# ..         ...        ...               ...              ...
# 471        NaN         49                40               21
# 472        NaN         48                33               19
# 473        NaN         49                33               21
# 474        NaN         59                43               31
# 475        NaN         53                24               27
# 476        NaN         68                39               36
# 477        NaN         70                36               48
# 478        NaN         77                35               42
# 479        NaN         72                32               48
# 480        NaN         40                34               11
# 481        NaN         44                38               15
# 482        NaN         50                44               24
# 483        NaN         71                38               48
# 484        NaN         76                61               47
# 485        NaN         75                29               52
# 486        NaN         87                34               61
# 487        NaN         65                34               39
# 488        NaN         63                32               38
# 489        NaN         55                24               30
# 490        NaN         53                22               30
# 491        NaN         80                38               56
# 492        NaN         71                66               44
# 493        NaN         64                58               36
# 494        NaN         60                44               32
# 495        NaN         61                47               36
# 496        NaN         69                50               37
# 497        NaN         68                49               38
# 498        NaN         64                28               36
# 499        NaN         68                32               41
# 500        NaN         87                39               56
#
#      research_mid_to_prize
# 0                        7
# 1                       19
# 2                       10
# 3                        8
# 4                       10
# 5                        6
# 6                       15
# 7                       26
# 8                        1
# 9                       12
# 10                      15
# 11                      21
# 12                      14
# 13                       2
# 14                      13
# 15                      14
# 16                      12
# 17                       3
# 18                      12
# 19                      22
# 20                      13
# 21                      -5
# 22                       9
# 23                      18
# 24                       1
# 25                      19
# 26                      21
# 27                      16
# 28                       3
# 29                       1
# ..                     ...
# 471                      9
# 472                     15
# 473                     16
# 474                     16
# 475                     29
# 476                     29
# 477                     34
# 478                     42
# 479                     40
# 480                      6
# 481                      6
# 482                      6
# 483                     33
# 484                     15
# 485                     46
# 486                     53
# 487                     31
# 488                     31
# 489                     31
# 490                     31
# 491                     42
# 492                      5
# 493                      6
# 494                     16
# 495                     14
# 496                     19
# 497                     19
# 498                     36
# 499                     36
# 500                     48
#
# [501 rows x 14 columns]

# %% [markdown]
# - Fundamentals of grouping
#   - group operations
#   - hierachal indexing
#
#
#
# ### Stats
#
# - Mean (and why it's misleading)
# - Median (and why it's misleading)
# - Quantile
# - Histogram
#
# - Standard deviation
# - Correlation
#
# ### Statistical tests
#
# - What is the issue with just comparing the numbers?
# - What a statistical significance test isn't
# - p and $\alpha$
# - Power calculation (optional)
# - Significance testing by simulation

# %%
police = pd.read_csv("police_killings.csv")

# %%
police.cause.value_counts()
# Out:
# Gunshot              411
# Taser                 27
# Death in custody      14
# Struck by vehicle     12
# Unknown                3
# dtype: int64

# %%
police.groupby('raceethnicity')['name'].count()
# Out:
# raceethnicity
# Asian/Pacific Islander     10
# Black                     135
# Hispanic/Latino            67
# Native American             4
# Unknown                    15
# White                     236
# Name: name, dtype: int64

# %%
france = pd.read_csv("CausesOfDeath_France_2001-2008.csv")

# %%
france
# Out:
#       TIME     GEO    UNIT      SEX    AGE  \
# 0     2001  France  Number    Males  Total
# 1     2001  France  Number    Males  Total
# 2     2001  France  Number    Males  Total
# 3     2001  France  Number    Males  Total
# 4     2001  France  Number    Males  Total
# 5     2001  France  Number    Males  Total
# 6     2001  France  Number    Males  Total
# 7     2001  France  Number    Males  Total
# 8     2001  France  Number    Males  Total
# 9     2001  France  Number    Males  Total
# 10    2001  France  Number    Males  Total
# 11    2001  France  Number    Males  Total
# 12    2001  France  Number    Males  Total
# 13    2001  France  Number    Males  Total
# 14    2001  France  Number    Males  Total
# 15    2001  France  Number    Males  Total
# 16    2001  France  Number    Males  Total
# 17    2001  France  Number    Males  Total
# 18    2001  France  Number    Males  Total
# 19    2001  France  Number    Males  Total
# 20    2001  France  Number    Males  Total
# 21    2001  France  Number    Males  Total
# 22    2001  France  Number    Males  Total
# 23    2001  France  Number    Males  Total
# 24    2001  France  Number    Males  Total
# 25    2001  France  Number    Males  Total
# 26    2001  France  Number    Males  Total
# 27    2001  France  Number    Males  Total
# 28    2001  France  Number    Males  Total
# 29    2001  France  Number    Males  Total
# ...    ...     ...     ...      ...    ...
# 1026  2008  France  Number  Females  Total
# 1027  2008  France  Number  Females  Total
# 1028  2008  France  Number  Females  Total
# 1029  2008  France  Number  Females  Total
# 1030  2008  France  Number  Females  Total
# 1031  2008  France  Number  Females  Total
# 1032  2008  France  Number  Females  Total
# 1033  2008  France  Number  Females  Total
# 1034  2008  France  Number  Females  Total
# 1035  2008  France  Number  Females  Total
# 1036  2008  France  Number  Females  Total
# 1037  2008  France  Number  Females  Total
# 1038  2008  France  Number  Females  Total
# 1039  2008  France  Number  Females  Total
# 1040  2008  France  Number  Females  Total
# 1041  2008  France  Number  Females  Total
# 1042  2008  France  Number  Females  Total
# 1043  2008  France  Number  Females  Total
# 1044  2008  France  Number  Females  Total
# 1045  2008  France  Number  Females  Total
# 1046  2008  France  Number  Females  Total
# 1047  2008  France  Number  Females  Total
# 1048  2008  France  Number  Females  Total
# 1049  2008  France  Number  Females  Total
# 1050  2008  France  Number  Females  Total
# 1051  2008  France  Number  Females  Total
# 1052  2008  France  Number  Females  Total
# 1053  2008  France  Number  Females  Total
# 1054  2008  France  Number  Females  Total
# 1055  2008  France  Number  Females  Total
#
#                                                   ICD10    Value  \
# 0       All causes of death (A00-Y89) excluding S00-T98  277 858
# 1     Certain infectious and parasitic diseases (A00...    5 347
# 2                                          Tuberculosis      545
# 3                               Meningococcal infection       30
# 4                                       Viral hepatitis      471
# 5            Human immunodeficiency virus [HIV] disease      892
# 6                                             Neoplasms   91 737
# 7                         Malignant neoplasms (C00-C97)   88 481
# 8       Malignant neoplasm of lip, oral cavity, pharynx    3 755
# 9                      Malignant neoplasm of oesophagus    3 442
# 10                        Malignant neoplasm of stomach    3 213
# 11                          Malignant neoplasm of colon    6 274
# 12    Malignant neoplasm of rectosigmoid junction, r...    2 242
# 13    Malignant neoplasm of liver and intrahepatic b...    5 258
# 14                       Malignant neoplasm of pancreas    3 788
# 15    Malignant neoplasm of larynx,  trachea, bronch...   22 457
# 16                           Malignant melanoma of skin      761
# 17                         Malignant neoplasm of breast      177
# 18                   Malignant neoplasm of cervix uteri        :
# 19          Malignant neoplasm of other parts of uterus        :
# 20                          Malignant neoplasm of ovary        :
# 21                       Malignant neoplasm of prostate    9 327
# 22    Malignant neoplasm of kidney, except renal pelvis    1 937
# 23                        Malignant neoplasm of bladder    3 231
# 24    Malignant neoplasms, stated or presumed to be ...    6 863
# 25    Diseases of the blood and blood-forming organs...    1 000
# 26    Endocrine, nutritional and metabolic diseases ...    8 356
# 27                                    Diabetes mellitus    5 318
# 28           Mental and behavioural disorders (F00-F99)    7 468
# 29    Mental and behavioural disorders due to use of...    2 523
# ...                                                 ...      ...
# 1026                           Cerebrovascular diseases   19 211
# 1027       Diseases of the respiratory system (J00-J99)   15 743
# 1028                                          Influenza      124
# 1029                                          Pneumonia    5 701
# 1030                 Chronic lower respiratory diseases    3 483
# 1031                      Asthma and status asthmaticus      613
# 1032         Diseases of the digestive system (K00-K93)   11 049
# 1033             Ulcer of stomach, duodenum and jejunum      448
# 1034                              Chronic liver disease    2 234
# 1035  Diseases of the skin and subcutaneous tissue (...    1 124
# 1036  Diseases of the musculoskeletal system and con...    2 399
# 1037  Rheumatoid arthritis and arthrosis (M05-M06,M1...      505
# 1038    Diseases of the genitourinary system  (N00-N99)    4 676
# 1039                      Diseases of kidney and ureter    3 606
# 1040  Pregnancy, childbirth and the puerperium (O00-...       64
# 1041  Certain conditions originating in the perinata...      695
# 1042  Congenital malformations, deformations and chr...      740
# 1043     Congenital malformations of the nervous system       59
# 1044  Congenital malformations of the circulatory sy...      261
# 1045  Symptoms, signs and abnormal clinical and labo...   20 789
# 1046                       Sudden infant death syndrome      109
# 1047        Ill-defined and unknown causes of mortality    6 305
# 1048  External causes of morbidity and mortality (V0...   14 861
# 1049                                          Accidents   11 051
# 1050                      Transport accidents (V01-V99)    1 045
# 1051                                              Falls    2 815
# 1052  Accidental poisoning by and exposure to noxiou...      630
# 1053                              Intentional self-harm    2 768
# 1054                                            Assault      166
# 1055                       Event of undetermined intent       68
#
#       Flag and Footnotes
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# 5                    NaN
# 6                    NaN
# 7                    NaN
# 8                    NaN
# 9                    NaN
# 10                   NaN
# 11                   NaN
# 12                   NaN
# 13                   NaN
# 14                   NaN
# 15                   NaN
# 16                   NaN
# 17                   NaN
# 18                   NaN
# 19                   NaN
# 20                   NaN
# 21                   NaN
# 22                   NaN
# 23                   NaN
# 24                   NaN
# 25                   NaN
# 26                   NaN
# 27                   NaN
# 28                   NaN
# 29                   NaN
# ...                  ...
# 1026                 NaN
# 1027                 NaN
# 1028                 NaN
# 1029                 NaN
# 1030                 NaN
# 1031                 NaN
# 1032                 NaN
# 1033                 NaN
# 1034                 NaN
# 1035                 NaN
# 1036                 NaN
# 1037                 NaN
# 1038                 NaN
# 1039                 NaN
# 1040                 NaN
# 1041                 NaN
# 1042                 NaN
# 1043                 NaN
# 1044                 NaN
# 1045                 NaN
# 1046                 NaN
# 1047                 NaN
# 1048                 NaN
# 1049                 NaN
# 1050                 NaN
# 1051                 NaN
# 1052                 NaN
# 1053                 NaN
# 1054                 NaN
# 1055                 NaN
#
# [1056 rows x 8 columns]
